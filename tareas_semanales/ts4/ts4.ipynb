# %% [markdown]
# # TS4
# <div style="text-align: center;">
#   <img src="images/logo_utnba.png" width="400">
# </div>
#
#
# ![Plantilla](images/plantilla.png)
#
# Introduccion del tema

# %% [markdown]
# ## Punto 1
# Obtener la funcion transferencia ....

# %% [markdown]
# Aca una introduccion de bessel
#
# N = 2
#
# $$B_2(s) = (\frac{1}{s} + \frac{1}{\frac{3}{s}}) + 1 ⇒ B_2(s) = \frac{1}{s} + \frac{s}{3} + 1 ⇒ B_2(s) = \frac{3 + s^2 + 3s}{3s}$$
#
# $$senh(s) = s$$
#
# $$T(s) = \frac{\frac{1}{s}}{\frac{s^2 + 3s + 3}{3s}} ⇒ \boxed{T(s) = \frac{3}{s^2 + 3s + 3}}$$
#
# N = 3
#
# $$B_3(s) = \frac{1}{s} + \frac{1}{\frac{3}{s} + \frac{s}{5}} + 1 ⇒...resolviendo...⇒ B_3(s) = \frac{s^3 + 6s^2 + 15s + 15}{(15+s^2)s}$$
#
# $$senh(s) = s + \frac{s^3}{3!} ⇒ senh(s) = s + \frac{s^3}{6}$$
#
# $$T(s) = \frac{\frac{1}{s + \frac{s^3}{6}}}{\frac{s^3 + 6s^2 + 15s + 15}{(15+s^2)s}} ⇒ T(s) = \frac{s^3 + 15s}{(s^3 + 6s^2 + 15s + 15)(s + \frac{s^3}{6})}$$
#
# Pero este no es el bessel de orden 3, nos falta la condicion de que en T(0)=1 por lo que nos queda de la siguiente manera.
#
# $$\boxed{T(s) = \frac{15}{s^3 + 6s^2 + 15s + 15}}$$
#
# N=4
#
# $$B_4(s) = \frac{1}{s} + \frac{3}{s + \frac{1}{\frac{5}{s} + \frac{s}{7}}} ⇒ ..operando.. ⇒ B_4(s) = s^4 + 10s^3 + 45s^2 + 105s + 105$$
#
# $$B_0(s) = 105$$
#
# $$\boxed{T(s) = \frac{15}{s^4 + 10s^3 + 45s^2 + 105s + 105}}$$

# %% [markdown]
# ## Punto 2
#
# Minimo orden

# %% [markdown]
# $$I..α(ω) = \frac{1}{|T(j\omega)|}$$
#
# Tambien sabemos que el maximo esta en $w=1$ por lo que podemos llegar a la siguiente conclusion
#
# $$α(w=1) = \frac{1}{|T(j1)|} = α_{max}$$
#
# $$α_{max\_db} = 20 \cdot log_{10}(\frac{1}{|T(j1)|}) = - 20\cdot log_{10}(|T(j1)|)$$
# N=2.....
#
# $$T(s) = \frac{3}{s^2 + 3s + 3}$$
#
# $$T(jw)|_{s=jw} = \frac{3}{-w^2 + 3jw + 3} ⇒ T(jw) = \frac{3}{3 - w^2 + 3jw}$$
#
# $$|T(jw)| = \frac{3}{\sqrt{(3-w^2)^2 + (3w)^2}}$$
#
# Si lo aplico para mi $w$ deseado que en mi caso es $w=1$ entonces me queda de la siguiente manera:
#
# $$|T(j1)| = \frac{3}{\sqrt{13}}$$
#
# Y con este valor $|T(j1)|$ se puede sacar $\alpha_{max}$
#
# $$α{max\_db} = - 20\cdot log_{10}(\frac{3}{\sqrt{13}}) ⇒ \boxed{α{max\_db} = 1.59 dB}$$
#
# No cumple mis condiciones por lo que pruebo para N=3
#
# N=3
#
# $$T(s) = \frac{15}{s^3 + 6s^2 + 15s + 15}$$
#
# $$T(jw) = \frac{15}{-jw^3 - 6w^2 + 15jw + 15}$$
#
# $$|T(jw)| = \frac{15}{\sqrt{ (15-6w^2)^2 + (15w-w^3)^2 }}$$
#
# $$|T(j1)| = \frac{15}{\sqrt{ (15-6\cdot1^2)^2 + (15\cdot1-1^3)^2 }} ⇒ |T(j1)| = \frac{15}{\sqrt{277}} ≈ 0.901$$
#
# $$α{max\_db} = - 20\cdot log_{10}(\frac{15}{\sqrt{277}}) ⇒ \boxed{α{max\_db} = 0.903 dB}$$
#
# Se puede observar que para N=3 se cumple el $α{max\_db}$ sea igual o menor a 1.

# %% [markdown]
# ## Punto 3
#
# Evaluar retardo

# %% [markdown]
# $$T(s) = \frac{3}{s^2 + 3s + 3}$$
#
# $$D(w) = -\frac{∂θ}{∂w}$$
#
# $$T(jw) = \frac{3}{3 - w^2 + 3jw}$$
#
# $$θ(w) = - arctg(\frac{15 w - w^3}{15 - 6 w^2})$$
#
# Aplicando la derivada me queda de la siguiente manera:
#
# $$D(w) = \frac{\frac{(15-2w^2)(15-6w^2) - (15w-w^3)(-12w)}{(15-6w^2)^2}}{1 + (\frac{15 w - w^3}{15 - 6 w^2})^2}$$
#
# Un poquito larga la ecuacion, pero nosotros queremos evaluar para $w$ conocidos como 0 y 2.5 por lo que simplemente reemplazo en la ecuacion y nos quedan los siguientes valores:
#
# $$D(w=0) = 1$$
#
# $$D(w=2.5) = 0.752$$
#
# $$\%error = \frac{D(w=0) - D(w=2.5)}{D(w=0)}\cdot 100\% = \frac{1-0.752}{1}$$
#
# $$\%error = 24.8 \%$$

# %% [markdown]
# ## Punto 4
#
# Sintetizar

# %% [markdown]
# ![Plantilla](images/sallen_key.png)
#
# $$H(s) = \frac{\frac{1}{R_1R_2C_1C_2}}{s^2 + s\frac{1}{R_2C_2}(1 + \frac{R_2}{C_2}) + \frac{1}{R_1R_2C_1C_2}} $$
#
# normalizado a w0=1 y R1, C1 nos queda lo siguiente
#
# $$H(s) = \frac{1}{s^2 + s\frac{1}{Q} + 1}$$
#
# con $r = \frac{R_2}{R_1}$, $c = \frac{C_2}{C_1}$, $r\cdot c = 1$, $w_0=1$, $Q=\frac{1}{1+r}$
#
# Bueno tengo el filtro pero mi bessel es de orden 3, por lo que desconpomgo mi bessel en una SOS y otra de orden 1.
#
# $$T(s) = \frac{15}{s^3 + 6s^2 + 15s + 15}$$
#
# $$(s+a)(s^2+bs+c) = s^3 + 6s^2 + 15s + 15$$
#
# Operando un poco se puede obtener los siguientes valores....
#
# $a = 1.31$ , $b=4.69$, $c=11.48$
#
#
# $$T(s) = \frac{15}{(s+1.31)(s^2+4.69s+11.48)}$$
#
# $$T(s) = \frac{1.31}{(s+1.31)}\cdot \frac{11.45}{(s^2+4.69s+11.48)}$$
#
# Los separo de esta manera para que el pasivo de orden 1 pueda ganar 1 para w=0.
#
# El SOS se puede considerar que gana 1 para w=0 por lo que puede ser posible realizarlo con el filtro sillen-key propuesto, pero aun no se sobre el Q por lo que realizo la verificacion de si es posible realizarlo.
#
# $$w_0^2 = 11.48 ⇒ w_0 = 3.39$$
#
# $$\frac{w_0}{Q} = 4.69 ⇒ Q = 0.72$$
#
# Bueno veo que tengo un Q un poco alto, pero verifico si es posible realizarlo con la topologia propuesta.
#
# Recordando que el $Q=\frac{1}{1+r}$ bueno entonces reemplazando
#
# $$0.72 = \frac{1}{1 + r} ⇒ r = \frac{1}{Q} - 1 ⇒ r = 0.39$$
#
# $$r \cdot c = 1 ⇒ c = 2.56$$
#
# Bueno no sucede ninguna contradiccion por lo que es posible realizarlo.
#
# Entonces empiezo a considerar valores $R_1=1$, $C_1=1$, $R_2=0.39$, $C_2=2.56$
#
# Estos son los valores normalizados para $w_0=1$, pero en mi SOS la $w_0$ no esta en 1 esta en 3.39 por lo que tengo que desnormalizar y me queda de la siguiente manera los valores.
#
# $R_1=1$, $C_1=0.29$, $R_2=0.39$, $C_2=0.76$
#
#
# Ahora llendo al filtro de primer orden lo sitentizo con un RC
#
# $T(s) = \frac{\frac{1}{RC}}{s + \frac{1}{RC}}$
#
# $w_0 = \frac{1}{RC}$
#
# Si lo dejo normalizado a $w_0=1$ me queda lo siguiente:
#
# $$RC = 1$$
#
# y si tomo $R=1$ entonces $C=1$
#
# Bueno si lo tomara para la frecuencia dada me queda de la siguiente manera
#
# $$1.31 = \frac{1}{RC} ⇒ C = \frac{1}{R\cdot 1.31}$$
#
# y si tomo $R=1$ tengo $C=0.76$

# %% [markdown]
# ## Muestra en python
#
# Todo lo normalize para w0=1, en los T(S) de bessel de orden 3 esta para un $w_0^3 = 15$ pero lo normalize para $w_0 = 1$

# %%
import scipy.signal as sig
import matplotlib.pyplot as plt
import numpy as np
import control

#recordar que todo esta normalizado para w0=1

w = np.logspace(-2, 2, 500)
#%% Con python
b, a = sig.bessel(N=3, Wn=1, btype='low', analog=True)
wt_p, ht_p = sig.freqs(b, a, worN=w)


#%% esto realizandolo con expandidas

# si lo normalizo me quedaria de la siguiente manera
#sys1_num = control.tf([1.31],[1, 1.31])
#sys2_num = control.tf([11.45],[1, 4.69, 11.45])

sys1_num = control.tf([1],[1, 1])
sys2_num = control.tf([1],[1, 1/0.72, 1])

syst_num = control.series(sys1_num, sys2_num)

mag_1, phase_1, w_1 = control.bode(sys1_num, w, plot=False)
mag_2, phase_2, w_2 = control.bode(sys2_num, w, plot=False)
mag_t, phase_t, w_t = control.bode(syst_num, w, plot=False)

#%%
#normalizado a w0=1
num = [15]
den = [1, 6, 15, 15]

#el w0 del de orden 3 es raiz cubica(15)
num, den = sig.lp2lp(num, den, 1/np.cbrt(15))

wt, ht = sig.freqs(num, den, w)

plt.figure(figsize=(12,6))

plt.semilogx(wt, 20*np.log10(abs(ht)))
plt.semilogx(wt_p, 20*np.log10(abs(ht_p)))
plt.semilogx(w_t, 20 *np.log10(abs(mag_t)))
plt.semilogx(w_2, 20 *np.log10(abs(mag_2)), '--')
plt.semilogx(w_1, 20 *np.log10(abs(mag_1)), '--')


plt.legend(['original', 'python', 'numerica','SOS_numerica', 'orden 1_numerica'])
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud [dB]")
plt.grid()
plt.show()
# Out:
# D:\spyder projects\.venv\Lib\site-packages\control\freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
